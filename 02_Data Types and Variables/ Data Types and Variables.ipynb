# %%
#Data Types
type(2)
# Out:
# int

# %%
type(3.1)
# Out:
# float

# %%
type(1.0)
# Out:
# float

# %%
type('a')
# Out:
# str

# %%
type(['hi', 199, 3.4])
# Out:
# list

# %%
type(('hi',23,3.0))
# Out:
# tuple

# %%
type(True)
# Out:
# bool

# %%
type({"Name":"James","ID":"180803"})
# Out:
# dict

# %%
#Variables 
"Hellow"
# Out:
# 'Hellow'

# %%
greetings = 'Hellow'

# %%
print(greetings)
# Out:
# Hellow

# %%
print(greetings + " Watson Crick")
# Out:
# Hellow Watson Crick

# %%
print(greetings + " Dr. Anal, Welcome to Jurassic Park! ")
# Out:
# Hellow Dr. Anal, Welcome to Jurassic Park!

# %%
#Dynamic Typing Variables

GOD = 1

print(GOD)
# Out:
# 1

# %%
GOD = ['Allah']

# %%
print(GOD)
# Out:
# ['Allah']

# %%
#In this is dynamic variables can be set where previously I set 1 later 'Allah'. that's why this is flexiable unlike other programming language.
