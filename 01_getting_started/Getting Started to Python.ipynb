# %%
print ('Hello world')
# Out:
# Hello world

# %%
print (" Hello world")
# Out:
#  Hello world

# %%
print ('hello world")
# Out:
#   Cell In[3], line 1
#     print ('hello world")
#            ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print ('he's a good by')
# Out:
#   Cell In[4], line 1
#     print ('he's a good by')
#                           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print ("he's a good a boy")
# Out:
# he's a good a boy
