# %%
3+2
# Out:
# 5

# %%
3-2
# Out:
# 1

# %%
3*2
# Out:
# 6

# %%
3/2
# Out:
# 1.5

# %%
3//2
#float division decemal excluded
# Out:
# 1

# %%
3**2
#exponential
# Out:
# 9

# %%
3>2
# Out:
# True

# %%
3>4
# Out:
# False

# %%
3==3
# Out:
# True

# %%
3==5
# Out:
# False

# %%
4>=3
# Out:
# True

# %%
4<=3
# Out:
# False

# %%
4>3 and 3>2
# Out:
# True

# %%
4>3 and 3<2
# Out:
# False

# %%
4>3 or 3>2
# Out:
# True

# %%
4>3 or 3<2
# Out:
# True

# %%
#not always reverse the output
not(4>3 or 3<2)
# Out:
# False

# %%
'123' in '12345'
# Out:
# True

# %%
'123' not in '4678'
# Out:
# True
